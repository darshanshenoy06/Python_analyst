# %% [markdown]
# <a href="https://colab.research.google.com/github/darshanshenoy06/Python_analyst/blob/main/modules/Dummy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dummy_df = pd.DataFrame({

            "Employee":["John","Mike","Sarah","Tom","Mike"],
            "Department":["IT","HR","IT","Finance","HR"],
            "Salary":[50000,60000,70000,55000,60000],
            "City":["Bangalore","Mumbai","Bangalore","Delhi","Mumbai"]

})
dummy_df.head().style.hide(axis= "index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfe24" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_dfe24_level0_col0" class="col_heading level0 col0" >Employee</th>
#       <th id="T_dfe24_level0_col1" class="col_heading level0 col1" >Department</th>
#       <th id="T_dfe24_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_dfe24_level0_col3" class="col_heading level0 col3" >City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dfe24_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_dfe24_row0_col1" class="data row0 col1" >IT</td>
#       <td id="T_dfe24_row0_col2" class="data row0 col2" >50000</td>
#       <td id="T_dfe24_row0_col3" class="data row0 col3" >Bangalore</td>
#     </tr>
#     <tr>
#       <td id="T_dfe24_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_dfe24_row1_col1" class="data row1 col1" >HR</td>
#       <td id="T_dfe24_row1_col2" class="data row1 col2" >60000</td>
#       <td id="T_dfe24_row1_col3" class="data row1 col3" >Mumbai</td>
#     </tr>
#     <tr>
#       <td id="T_dfe24_row2_col0" class="data row2 col0" >Sarah</td>
#       <td id="T_dfe24_row2_col1" class="data row2 col1" >IT</td>
#       <td id="T_dfe24_row2_col2" class="data row2 col2" >70000</td>
#       <td id="T_dfe24_row2_col3" class="data row2 col3" >Bangalore</td>
#     </tr>
#     <tr>
#       <td id="T_dfe24_row3_col0" class="data row3 col0" >Tom</td>
#       <td id="T_dfe24_row3_col1" class="data row3 col1" >Finance</td>
#       <td id="T_dfe24_row3_col2" class="data row3 col2" >55000</td>
#       <td id="T_dfe24_row3_col3" class="data row3 col3" >Delhi</td>
#     </tr>
#     <tr>
#       <td id="T_dfe24_row4_col0" class="data row4 col0" >Mike</td>
#       <td id="T_dfe24_row4_col1" class="data row4 col1" >HR</td>
#       <td id="T_dfe24_row4_col2" class="data row4 col2" >60000</td>
#       <td id="T_dfe24_row4_col3" class="data row4 col3" >Mumbai</td>
#     </tr>
#   </tbody>
# </table>

# %%
dummy_df['Department']
# Out:
# 0         IT
# 1         HR
# 2         IT
# 3    Finance
# 4         HR
# Name: Department, dtype: object

# %%
dummy_df
# Out:
#   Employee Department  Salary       City
# 0     John         IT   50000  Bangalore
# 1     Mike         HR   60000     Mumbai
# 2    Sarah         IT   70000  Bangalore
# 3      Tom    Finance   55000      Delhi
# 4     Mike         HR   60000     Mumbai

# %%
dummy_df[dummy_df['Salary']>55000].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b21f5" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_b21f5_level0_col0" class="col_heading level0 col0" >Employee</th>
#       <th id="T_b21f5_level0_col1" class="col_heading level0 col1" >Department</th>
#       <th id="T_b21f5_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_b21f5_level0_col3" class="col_heading level0 col3" >City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b21f5_row0_col0" class="data row0 col0" >Mike</td>
#       <td id="T_b21f5_row0_col1" class="data row0 col1" >HR</td>
#       <td id="T_b21f5_row0_col2" class="data row0 col2" >60000</td>
#       <td id="T_b21f5_row0_col3" class="data row0 col3" >Mumbai</td>
#     </tr>
#     <tr>
#       <td id="T_b21f5_row1_col0" class="data row1 col0" >Sarah</td>
#       <td id="T_b21f5_row1_col1" class="data row1 col1" >IT</td>
#       <td id="T_b21f5_row1_col2" class="data row1 col2" >70000</td>
#       <td id="T_b21f5_row1_col3" class="data row1 col3" >Bangalore</td>
#     </tr>
#     <tr>
#       <td id="T_b21f5_row2_col0" class="data row2 col0" >Mike</td>
#       <td id="T_b21f5_row2_col1" class="data row2 col1" >HR</td>
#       <td id="T_b21f5_row2_col2" class="data row2 col2" >60000</td>
#       <td id="T_b21f5_row2_col3" class="data row2 col3" >Mumbai</td>
#     </tr>
#   </tbody>
# </table>

# %%
dummy_df[(dummy_df['Department']== "HR") & (dummy_df['Salary']>= 60000)]
# Out:
#   Employee Department  Salary    City
# 1     Mike         HR   60000  Mumbai
# 4     Mike         HR   60000  Mumbai
