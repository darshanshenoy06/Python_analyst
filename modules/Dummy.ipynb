# %% [markdown]
# <a href="https://colab.research.google.com/github/darshanshenoy06/Python_analyst/blob/main/modules/Dummy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dummy_df = pd.DataFrame({

            "Employee":["John","Mike","Sarah","Tom","Mike"],
            "Department":["IT","HR","IT","Finance","HR"],
            "Salary":[50000,60000,70000,55000,60000],
            "City":["Bangalore","Mumbai","Bangalore","Delhi","Mumbai"]

})
dummy_df.head().style.hide(axis= "index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_06448" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_06448_level0_col0" class="col_heading level0 col0" >Employee</th>
#       <th id="T_06448_level0_col1" class="col_heading level0 col1" >Department</th>
#       <th id="T_06448_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_06448_level0_col3" class="col_heading level0 col3" >City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_06448_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_06448_row0_col1" class="data row0 col1" >IT</td>
#       <td id="T_06448_row0_col2" class="data row0 col2" >50000</td>
#       <td id="T_06448_row0_col3" class="data row0 col3" >Bangalore</td>
#     </tr>
#     <tr>
#       <td id="T_06448_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_06448_row1_col1" class="data row1 col1" >HR</td>
#       <td id="T_06448_row1_col2" class="data row1 col2" >60000</td>
# ...

# %%
dummy_df['Department']
# Out:
# 0         IT
# 1         HR
# 2         IT
# 3    Finance
# 4         HR
# Name: Department, dtype: object

# %%
dummy_df
# Out:
#   Employee Department  Salary       City
# 0     John         IT   50000  Bangalore
# 1     Mike         HR   60000     Mumbai
# 2    Sarah         IT   70000  Bangalore
# 3      Tom    Finance   55000      Delhi
# 4     Mike         HR   60000     Mumbai

# %%
dummy_df[dummy_df['Salary']>55000].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c57b6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_c57b6_level0_col0" class="col_heading level0 col0" >Employee</th>
#       <th id="T_c57b6_level0_col1" class="col_heading level0 col1" >Department</th>
#       <th id="T_c57b6_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_c57b6_level0_col3" class="col_heading level0 col3" >City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c57b6_row0_col0" class="data row0 col0" >Mike</td>
#       <td id="T_c57b6_row0_col1" class="data row0 col1" >HR</td>
#       <td id="T_c57b6_row0_col2" class="data row0 col2" >60000</td>
#       <td id="T_c57b6_row0_col3" class="data row0 col3" >Mumbai</td>
#     </tr>
#     <tr>
#       <td id="T_c57b6_row1_col0" class="data row1 col0" >Sarah</td>
#       <td id="T_c57b6_row1_col1" class="data row1 col1" >IT</td>
#       <td id="T_c57b6_row1_col2" class="data row1 col2" >70000</td>
# ...

# %%
dummy_df[(dummy_df['Department']== "HR") & (dummy_df['Salary']>= 60000)]
# Out:
#   Employee Department  Salary    City
# 1     Mike         HR   60000  Mumbai
# 4     Mike         HR   60000  Mumbai

# %%
dummy_df.sort_values("Salary",ascending=False)
# Out:
#   Employee Department  Salary       City
# 2    Sarah         IT   70000  Bangalore
# 4     Mike         HR   60000     Mumbai
# 1     Mike         HR   60000     Mumbai
# 3      Tom    Finance   55000      Delhi
# 0     John         IT   50000  Bangalore

# %%
missing_values = pd.DataFrame({
    "Employee":["John","Mike","Sarah","Tom"],
    "Salary":[50000,None,70000,None],
    "Department":["IT","HR","IT","Finance"]
})

# %%
missing_values.head()
# Out:
#   Employee   Salary Department
# 0     John  50000.0         IT
# 1     Mike      NaN         HR
# 2    Sarah  70000.0         IT
# 3      Tom      NaN    Finance

# %%
missing_values.isnull()
# Out:
#    Employee  Salary  Department
# 0     False   False       False
# 1     False    True       False
# 2     False   False       False
# 3     False    True       False

# %%
missing_values.isnull().sum()
# Out:
# Employee      0
# Salary        2
# Department    0
# dtype: int64

# %%
missing_values['Salary'].fillna(0)
# Out:
# 0    50000.0
# 1        0.0
# 2    70000.0
# 3        0.0
# Name: Salary, dtype: float64

# %%
missing_values['Salary'].fillna(0)
# Out:
# 0    50000.0
# 1        0.0
# 2    70000.0
# 3        0.0
# Name: Salary, dtype: float64

# %%
missing_values
# Out:
#   Employee   Salary Department
# 0     John  50000.0         IT
# 1     Mike      NaN         HR
# 2    Sarah  70000.0         IT
# 3      Tom      NaN    Finance

# %%
dummy_df['Salary'] = dummy_df['Salary'].fillna(0)
dummy_df
# Out:
#   Employee Department  Salary       City
# 0     John         IT   50000  Bangalore
# 1     Mike         HR   60000     Mumbai
# 2    Sarah         IT   70000  Bangalore
# 3      Tom    Finance   55000      Delhi
# 4     Mike         HR   60000     Mumbai

# %% [markdown]
# Create a null Value

# %%
dummy_df.loc[1, 'Salary'] = None
dummy_df
# Out:
#   Employee Department   Salary       City
# 0     John         IT  50000.0  Bangalore
# 1     Mike         HR      NaN     Mumbai
# 2    Sarah         IT  70000.0  Bangalore
# 3      Tom    Finance  55000.0      Delhi
# 4     Mike         HR  60000.0     Mumbai

# %%
dummy_df.isnull().sum()
# Out:
# Employee      0
# Department    0
# Salary        1
# City          0
# dtype: int64

# %%
dummy_df['Salary'] = dummy_df['Salary'].fillna(0)
dummy_df
# Out:
#   Employee Department   Salary       City
# 0     John         IT  50000.0  Bangalore
# 1     Mike         HR      0.0     Mumbai
# 2    Sarah         IT  70000.0  Bangalore
# 3      Tom    Finance  55000.0      Delhi
# 4     Mike         HR  60000.0     Mumbai

# %%
dummy_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
dummy_df.loc[4] = dummy_df.loc[1]
dummy_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
dummy_df.duplicated(subset=['Department'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool
